# %% [markdown]
# ## AIVLE School [AI 미니프로젝트] '서울시 생활정보 기반 대중교통 수요 분석'

# %% [markdown]
# ---

# %% [markdown]
# # 4. 구 별 업종 분석
# ### 서울시 내 각 구 별로 등록업종을 분석합니다.

# %% [markdown]
# ## 데이터 안내
#
# [데이터 파일명]
# * 4. seoul_people.csv
#
# [데이터 정보]
# * 서울 시 구별 등록 업종 상위 10개 데이터
#     * 택시운송업
#     * 한식일반음식점업
#     * 용달 화물자동차 운송업
#     * 부동산 중개 및 대리업
#     * 두발미용업
#     * 커피전문점
#     * 남녀용 겉옷 및 셔츠 도매업
#     * 기타주점업
#     * 일반 교과 학원
#     * 한식 육류요리 전문점
#
# [데이터 컬럼 정보]
# * 다수 업종 상위 1~10

# %%
# 필요 라이브러리를 설치합니다.
#%pip install pandas seaborn

# %% [markdown]
# ---

# %% [markdown]
# # 4.1.데이터 불러오기

# %% [markdown]
# #### [4.1.1] 데이터 로딩
# * Pandas 라이브러리를 활용해서 '4. business_type.csv'파일을 'seoul_business' 변수에 저장하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * 인코더를 사용해 주세요
#     * 데이터를 불러올 때 오류가 발생한다면, 오류에 대해 직접 검색하여 해결해보세요.

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
import pandas as pd
import numpy as np

seoul_business=pd.read_csv("4. business_type.csv",sep=',')
seoul_business
# Out:
#      자치구     동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3   다수업종 상위10.4  \
# 0    자치구     동     택시운송업       택시운송업  한식 일반 음식점업  한식 일반 음식점업  용달 화물자동차 운송업
# 1    자치구     동      사업체수        종사자수        사업체수        종사자수          사업체수
# 2     합계    합계    47,176      76,701      29,225     100,183        28,494
# 3    종로구    소계       215         215       1,548       5,912           618
# 4    종로구   사직동         7           7         230         982            12
# ..   ...   ...       ...         ...         ...         ...           ...
# 446  강동구  성내3동       120         120         135         390            73
# 447  강동구  둔촌2동       117         436          63         249            89
# 448  강동구  암사1동       209         372          71         195           153
# 449  강동구  천호2동       157         187         152         509           144
# 450  강동구    길동     1,441       1,557         152         436           217
#
# ...

# %%
# 데이터 프레임의 Shape을 확인합니다.
seoul_business.shape
# Out:
# (451, 22)

# %% [markdown]
# ---

# %% [markdown]
# # 4.2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [4.2.1] 기본 정보 확인하기
# * 'seoul_business' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head', 'tail' 등 전부 활용해 보겠습니다.

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
seoul_business.describe()
# Out:
#         자치구    동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4  \
# count   451  451       451         451         451         451         451
# unique   27  425       226         280         176         305         177
# top     송파구   소계        71          11          24         104          56
# freq     28   25         7           7          11           6           8
#
#        다수업종 상위10.5 다수업종 상위10.6 다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# count          451         451         451  ...          451          451
# unique         180         142         205  ...          131          239
# top             56          40          54  ...           13           16
# freq             9          11           9  ...           18            8
#
#        다수업종 상위10.12 다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15 다수업종 상위10.16  \
# count           451          451          451          451          451
# unique           69          147          127          189          113
# ...

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   자치구           451 non-null    object
#  1   동             451 non-null    object
#  2   다수업종 상위10     451 non-null    object
#  3   다수업종 상위10.1   451 non-null    object
#  4   다수업종 상위10.2   451 non-null    object
#  5   다수업종 상위10.3   451 non-null    object
#  6   다수업종 상위10.4   451 non-null    object
#  7   다수업종 상위10.5   451 non-null    object
#  8   다수업종 상위10.6   451 non-null    object
#  9   다수업종 상위10.7   451 non-null    object
#  10  다수업종 상위10.8   451 non-null    object
#  11  다수업종 상위10.9   451 non-null    object
#  12  다수업종 상위10.10  451 non-null    object
#  13  다수업종 상위10.11  451 non-null    object
#  14  다수업종 상위10.12  451 non-null    object
#  15  다수업종 상위10.13  451 non-null    object
#  16  다수업종 상위10.14  451 non-null    object
#  17  다수업종 상위10.15  451 non-null    object
# ...

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
seoul_business.head()
# Out:
#    자치구    동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3   다수업종 상위10.4  \
# 0  자치구    동     택시운송업       택시운송업  한식 일반 음식점업  한식 일반 음식점업  용달 화물자동차 운송업
# 1  자치구    동      사업체수        종사자수        사업체수        종사자수          사업체수
# 2   합계   합계    47,176      76,701      29,225     100,183        28,494
# 3  종로구   소계       215         215       1,548       5,912           618
# 4  종로구  사직동         7           7         230         982            12
#
#     다수업종 상위10.5   다수업종 상위10.6   다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# 0  용달 화물자동차 운송업  부동산 중개 및 대리업  부동산 중개 및 대리업  ...        커피전문점        커피전문점
# 1          종사자수          사업체수          종사자수  ...         사업체수         종사자수
# 2        29,356        24,013        42,636  ...       16,255       57,322
# 3           646           549           889  ...          948        3,613
# 4            12            57            96  ...          124          525
#
#       다수업종 상위10.12     다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15 다수업종 상위10.16  \
# ...

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
seoul_business.tail()
# Out:
#      자치구     동 다수업종 상위10 다수업종 상위10.1 다수업종 상위10.2 다수업종 상위10.3 다수업종 상위10.4  \
# 446  강동구  성내3동       120         120         135         390          73
# 447  강동구  둔촌2동       117         436          63         249          89
# 448  강동구  암사1동       209         372          71         195         153
# 449  강동구  천호2동       157         187         152         509         144
# 450  강동구    길동     1,441       1,557         152         436         217
#
#     다수업종 상위10.5 다수업종 상위10.6 다수업종 상위10.7  ... 다수업종 상위10.10 다수업종 상위10.11  \
# 446          73         104         163  ...           54          133
# 447          89          61         108  ...           34           85
# 448         153          67         107  ...           29           59
# 449         151          97         188  ...           63          212
# 450         225         146         237  ...           71          228
#
#     다수업종 상위10.12 다수업종 상위10.13 다수업종 상위10.14 다수업종 상위10.15 다수업종 상위10.16  \
# ...

# %% [markdown]
# #### [4.2.2] 원하는 데이터 형태로 저장하기
#
# * head, tail 등을 살펴본 결과를 토대로 header 값을 적절히 지정하여 데이터를 다시 불러오고 필요한 컬럼만 저장하세요

# %%
#read_csv 재실행. 단, header값을 적절히 지정
seoul_business=pd.read_csv("4. business_type.csv",header=[1,2],sep=',',thousands=',')
seoul_business
# Out:
#      자치구     동   택시운송업         한식 일반 음식점업         용달 화물자동차 운송업          \
#      자치구     동    사업체수    종사자수       사업체수    종사자수         사업체수    종사자수
# 0     합계    합계  47,176  76,701      29225  100183       28,494  29,356
# 1    종로구    소계     215     215       1548    5912          618     646
# 2    종로구   사직동       7       7        230     982           12      12
# 3    종로구   삼청동       5       5         42     145            4       4
# 4    종로구   부암동      22      22         26     100            9       9
# ..   ...   ...     ...     ...        ...     ...          ...     ...
# 444  강동구  성내3동     120     120        135     390           73      73
# 445  강동구  둔촌2동     117     436         63     249           89      89
# 446  강동구  암사1동     209     372         71     195          153     153
# 447  강동구  천호2동     157     187        152     509          144     151
# 448  강동구    길동   1,441   1,557        152     436          217     225
#
# ...

# %%
# 다시 불러온 데이터프레임에서 여러분 각자가 사용하고자 하는 컬럼만 가져오세요.
seoul_business.columns=['자치구','동','택시운송업_사업체수','택시운송업_종사자수','한식 일반 음식점업_사업체수','한식 일반 음식점업_종사자수',
                        '용달 화물자동차 운송업_사업체수','용달 화물자동차 운송업_종사자수','부동산 중개 및 대리업_사업체수','부동산 중개 및 대리업_종사자수',
                        '두발미용업_사업체수','두발미용업_종사자수','커피전문점_사업체수','커피전문점_종사자수',
                        '남녀용 겉옷 및 셔츠 도매업_사업체수','남녀용 겉옷 및 셔츠 도매업_종사자수','기타주점업_사업체수','기타주점업_종사자수',
                        '일반 교과 학원_사업체수','일반 교과 학원_종사자수','한식 육류요리 전문점_사업체수','한식 육류요리 전문점_종사자수']
seoul_business.head()
# Out:
#    자치구    동 택시운송업_사업체수 택시운송업_종사자수  한식 일반 음식점업_사업체수  한식 일반 음식점업_종사자수  \
# 0   합계   합계     47,176     76,701            29225           100183
# 1  종로구   소계        215        215             1548             5912
# 2  종로구  사직동          7          7              230              982
# 3  종로구  삼청동          5          5               42              145
# 4  종로구  부암동         22         22               26              100
#
#   용달 화물자동차 운송업_사업체수 용달 화물자동차 운송업_종사자수  부동산 중개 및 대리업_사업체수  부동산 중개 및 대리업_종사자수  \
# 0            28,494            29,356              24013              42636
# 1               618               646                549                889
# 2                12                12                 57                 96
# 3                 4                 4                  9                 10
# 4                 9                 9                 17                 26
#
#    ... 커피전문점_사업체수 커피전문점_종사자수  남녀용 겉옷 및 셔츠 도매업_사업체수  남녀용 겉옷 및 셔츠 도매업_종사자수  \
# ...

# %%
# 여러분 각자가 사용하고자 하는 형태로 데이터를 정리합니다. 
# 예를 들어, 동 컬럼의 값이 소계인 항목들만 골라내 보겠습니다. 
# 위와 같이 동 컬럼의 소계를 구하면 자치구 별 값이 되므로 이후에 동 컬럼은 삭제하겠습니다. 결과적으로 자치구 별 값을 얻게 됩니다.
new_df=seoul_business.loc[seoul_business['동']=='소계']
new_df.drop('동',axis=1,inplace=True)
new_df.head()
# Out:
#       자치구   동 택시운송업_사업체수 택시운송업_종사자수  한식 일반 음식점업_사업체수  한식 일반 음식점업_종사자수  \
# 1     종로구  소계        215        215             1548             5912
# 19     중구  소계        230        235             1588             6414
# 35    용산구  소계        416        523              857             2987
# 52    성동구  소계      1,200      2,527              956             2785
# 70    광진구  소계      1,119      1,744              963             2861
# 86   동대문구  소계      1,546      2,093             1236             3566
# 101   중랑구  소계      3,634      6,262              991             2479
# 118   성북구  소계      1,835      2,643              973             2822
# 139   강북구  소계      1,713      2,589              965             2663
# 153   도봉구  소계      2,993      5,783              672             2009
# 168   노원구  소계      4,114      6,074              866             2650
# 188   은평구  소계      3,108      4,430              881             2585
# ...

# %%
# 위에서 여러분 각자가 사용하고자 하는 형태로 정리한 해당 데이터프레임을 csv 파일('df_seoul_business.csv')로 저장하세요.
new_df.to_csv('df_seoul_business.csv')

# %% [markdown]
# ---

# %% [markdown]
# # 4.3.데이터 분석하기
# + 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별하세요.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
# 시각화 한글폰트 설정
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# %% [markdown]
# #### [4.3.1] 데이터 분포 알아보기_1
# * '자치구' 등 여러 변수를 기준으로 시각화 해보고 인사이트를 도출해보세요.

# %%
df=pd.read_csv('df_seoul_business.csv',index_col=0,thousands=',')
df=df.reset_index(drop=True)
df
# Out:
#      자치구  택시운송업_사업체수  택시운송업_종사자수  한식 일반 음식점업_사업체수  한식 일반 음식점업_종사자수  \
# 0    종로구         215         215             1548             5912
# 1     중구         230         235             1588             6414
# 2    용산구         416         523              857             2987
# 3    성동구        1200        2527              956             2785
# 4    광진구        1119        1744              963             2861
# 5   동대문구        1546        2093             1236             3566
# 6    중랑구        3634        6262              991             2479
# 7    성북구        1835        2643              973             2822
# 8    강북구        1713        2589              965             2663
# 9    도봉구        2993        5783              672             2009
# 10   노원구        4114        6074              866             2650
# 11   은평구        3108        4430              881             2585
# 12  서대문구        1747        2677              863             2694
# ...

# %%
# 위에서 여러분 각자가 사용하고자 하는 형태로 정리한 해당 데이터프레임을 csv 파일('df_seoul_business.csv')로 저장하세요.
df.to_csv('df_seoul_business.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   자치구                   25 non-null     object
#  1   택시운송업_사업체수            25 non-null     int64
#  2   택시운송업_종사자수            25 non-null     int64
#  3   한식 일반 음식점업_사업체수       25 non-null     int64
#  4   한식 일반 음식점업_종사자수       25 non-null     int64
#  5   용달 화물자동차 운송업_사업체수     25 non-null     int64
#  6   용달 화물자동차 운송업_종사자수     25 non-null     int64
#  7   부동산 중개 및 대리업_사업체수     25 non-null     int64
#  8   부동산 중개 및 대리업_종사자수     25 non-null     int64
#  9   두발미용업_사업체수            25 non-null     int64
#  10  두발미용업_종사자수            25 non-null     int64
#  11  커피전문점_사업체수            25 non-null     int64
#  12  커피전문점_종사자수            25 non-null     int64
#  13  남녀용 겉옷 및 셔츠 도매업_사업체수  25 non-null     int64
#  14  남녀용 겉옷 및 셔츠 도매업_종사자수  25 non-null     int64
# ...

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
plt.figure(figsize=(20,6))

plt.plot(df['자치구'],df['택시운송업_사업체수'],label='택시운송업')
plt.plot(df['자치구'],df['한식 일반 음식점업_사업체수'],label='한식 일반 음식점업')
plt.plot(df['자치구'],df['용달 화물자동차 운송업_사업체수'],label='용달 화물자동차 운송업')
plt.plot(df['자치구'],df['부동산 중개 및 대리업_사업체수'],label='부동산 중개 및 대리업')
plt.plot(df['자치구'],df['두발미용업_사업체수'],label='두발미용')
plt.plot(df['자치구'],df['커피전문점_사업체수'],label='커피전문점')
plt.plot(df['자치구'],df['남녀용 겉옷 및 셔츠 도매업_사업체수'],label='남녀용 겉옷 및 셔츠 도매업')
plt.plot(df['자치구'],df['기타주점업_사업체수'],label='기타주점업')
plt.plot(df['자치구'],df['일반 교과 학원_사업체수'],label='일반 교과 학원')
plt.plot(df['자치구'],df['한식 육류요리 전문점_사업체수'],label='한식 육류요리 전문점')

plt.xticks(rotation=45)
plt.legend(loc='best')
plt.show()

# %%
# 아래에 코드를 작성하고 결과를 확인합니다.
plt.figure(figsize=(20,6))

plt.plot(df['자치구'],df['택시운송업_종사자수'],label='택시운송업')
plt.plot(df['자치구'],df['한식 일반 음식점업_종사자수'],label='한식 일반 음식점업')
plt.plot(df['자치구'],df['용달 화물자동차 운송업_종사자수'],label='용달 화물자동차 운송업')
plt.plot(df['자치구'],df['부동산 중개 및 대리업_종사자수'],label='부동산 중개 및 대리업')
plt.plot(df['자치구'],df['두발미용업_종사자수'],label='두발미용')
plt.plot(df['자치구'],df['커피전문점_종사자수'],label='커피전문점')
plt.plot(df['자치구'],df['남녀용 겉옷 및 셔츠 도매업_종사자수'],label='남녀용 겉옷 및 셔츠 도매업')
plt.plot(df['자치구'],df['기타주점업_종사자수'],label='기타주점업')
plt.plot(df['자치구'],df['일반 교과 학원_종사자수'],label='일반 교과 학원')
plt.plot(df['자치구'],df['한식 육류요리 전문점_종사자수'],label='한식 육류요리 전문점')

plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.show()

# %%
selected_columns = ['택시운송업_종사자수', '한식 일반 음식점업_종사자수', '용달 화물자동차 운송업_종사자수', '부동산 중개 및 대리업_종사자수', '두발미용업_종사자수']
df[selected_columns].boxplot()
plt.title('주요 업종 종사자수 분포')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 위 차트를 통해 알게된 사실을 정리해봅시다.
# 1. 중구에 의류 도매업에 종사하는 인구 수 및 업체가 많다.
# 2. 강남구에 음식점업에 종사하는 인구 수 및 업체가 많다.
# 3. 강남구에 학원 업종에 종사하는 인구 수 및 업체가 많다.

# %% [markdown]
# ---
